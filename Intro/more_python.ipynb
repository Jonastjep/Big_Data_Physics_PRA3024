# %%
import cv2, numpy
from matplotlib import pyplot as plt

# %%
print(chr(43))
print(ord("+"))
# Out:
# +
# 43

# %%
def char_generator(message):
    for c in message:
        yield ord(c)
        
def load_img(img_path):
    img = cv2.imread(img_path)
    return img

def encode_img(img_path, message):
    message = char_generator(message)
    img = load_img(img_path)

# %%
img = cv2.imread("thermal2.png")
#converts from cv2 BRG to RGB recognized by matplotlib
img2 = img[:,:,::-1]

plt.imshow(img2)

# %%
# Good example of numpy array manipulation
# img = cv2.imread("thermal2.png")
# for i in range(len(img)):
#     img[i] = img[i].flatten()
#     for pix in img[i][::4]: #3very four
#         #something
#     img[i] = img[i].reshape(len(img[i]),3)

# %%
# Out:
# 1
# 3
# 5
# 7
# 9
